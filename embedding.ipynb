# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent=[  'the glass of milk',
        'the glass of juice',
        'the cup of tea',
        'I am a good boy',
        'I am a good developer',
        'understand the meaning of words',
        'your videos are good',]

sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## define the vocabulary size 

voc_size = 10000

# %%
## One Hot rep of every word 

one_hot_rep = [one_hot(words, voc_size) for words in sent]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
one_hot_rep
# Out:
# [[5881, 2317, 1351, 7350],
#  [5881, 2317, 1351, 694],
#  [5881, 352, 1351, 1984],
#  [6281, 5629, 8244, 4994, 4179],
#  [6281, 5629, 8244, 4994, 1363],
#  [3622, 5881, 4571, 1351, 2031],
#  [8908, 3409, 1457, 4994]]

# %%
## word embedding representation 

from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 8 

embedded_docs = pad_sequences(one_hot_rep, padding= 'pre', maxlen= sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 5881 2317 1351 7350]
#  [   0    0    0    0 5881 2317 1351  694]
#  [   0    0    0    0 5881  352 1351 1984]
#  [   0    0    0 6281 5629 8244 4994 4179]
#  [   0    0    0 6281 5629 8244 4994 1363]
#  [   0    0    0 3622 5881 4571 1351 2031]
#  [   0    0    0    0 8908 3409 1457 4994]]

# %%
## feature represntation 

dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size, dim, input_length = sent_length))
model.compile('adam', 'mse')
# Out:
# 2025-04-17 10:17:38.630487: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2025-04-17 10:17:38.630712: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-04-17 10:17:38.630732: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-04-17 10:17:38.631121: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-17 10:17:38.631439: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 2025-04-17 10:18:22.281942: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 296ms/step
# array([[[ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [-0.02591617, -0.00051349,  0.03782333, -0.02742329,
#           0.00983693, -0.00701687, -0.04394136, -0.00390934,
#           0.01345844, -0.01327621],
#         [-0.04100574,  0.02606461, -0.04599339,  0.02386352,
#           0.02503207, -0.03597945, -0.0194989 ,  0.02387352,
#           0.00207195, -0.02740302],
#         [-0.01656395, -0.02776014, -0.00654156, -0.01475537,
#          -0.02967867,  0.04146253,  0.01982585, -0.02761208,
#          -0.00329828,  0.04715735],
#         [ 0.01212822, -0.00125396, -0.01668574, -0.00634258,
#           0.03437657,  0.01033913, -0.02537197,  0.03823092,
#           0.00948141, -0.0268918 ]],
#
#        [[ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [-0.02591617, -0.00051349,  0.03782333, -0.02742329,
#           0.00983693, -0.00701687, -0.04394136, -0.00390934,
#           0.01345844, -0.01327621],
#         [-0.04100574,  0.02606461, -0.04599339,  0.02386352,
#           0.02503207, -0.03597945, -0.0194989 ,  0.02387352,
#           0.00207195, -0.02740302],
#         [-0.01656395, -0.02776014, -0.00654156, -0.01475537,
#          -0.02967867,  0.04146253,  0.01982585, -0.02761208,
#          -0.00329828,  0.04715735],
#         [-0.00525244, -0.03714929, -0.04086424,  0.04330528,
#          -0.01603945,  0.02289656,  0.03141197,  0.0166196 ,
#          -0.02349199,  0.00769873]],
#
#        [[ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [-0.02591617, -0.00051349,  0.03782333, -0.02742329,
#           0.00983693, -0.00701687, -0.04394136, -0.00390934,
#           0.01345844, -0.01327621],
#         [-0.02052212, -0.03023149,  0.02203721,  0.03675992,
#           0.04002103,  0.02015252,  0.04141379, -0.00290058,
#          -0.02662642, -0.02649171],
#         [-0.01656395, -0.02776014, -0.00654156, -0.01475537,
#          -0.02967867,  0.04146253,  0.01982585, -0.02761208,
#          -0.00329828,  0.04715735],
#         [ 0.02555836, -0.01318998, -0.02664049, -0.04091448,
#           0.01647354, -0.01580905, -0.0388523 ,  0.0021264 ,
#          -0.00567062,  0.04870442]],
#
#        [[ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [-0.01564944, -0.00397574,  0.0035722 , -0.04159571,
#           0.00779944,  0.0467901 ,  0.00851661,  0.01416098,
#           0.04498415, -0.04701046],
#         [-0.02852139, -0.03548105,  0.04841876, -0.04888938,
#          -0.03394109,  0.03448566, -0.0446776 ,  0.02396284,
#          -0.00845461,  0.04138574],
#         [-0.04609574,  0.02418463, -0.04035591, -0.0176249 ,
#          -0.04308171, -0.01323497, -0.0145781 ,  0.00556671,
#           0.00782851, -0.01748121],
#         [-0.00636522, -0.0300707 , -0.04812494, -0.04883038,
#          -0.00963491, -0.00887865, -0.01811876,  0.04205158,
#           0.0070897 ,  0.00178963],
#         [-0.01553466, -0.03921971, -0.03874552, -0.00408291,
#          -0.01251239,  0.03697339,  0.04100101, -0.012067  ,
#           0.02236158,  0.04792264]],
#
#        [[ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [-0.01564944, -0.00397574,  0.0035722 , -0.04159571,
#           0.00779944,  0.0467901 ,  0.00851661,  0.01416098,
#           0.04498415, -0.04701046],
#         [-0.02852139, -0.03548105,  0.04841876, -0.04888938,
#          -0.03394109,  0.03448566, -0.0446776 ,  0.02396284,
#          -0.00845461,  0.04138574],
#         [-0.04609574,  0.02418463, -0.04035591, -0.0176249 ,
#          -0.04308171, -0.01323497, -0.0145781 ,  0.00556671,
#           0.00782851, -0.01748121],
#         [-0.00636522, -0.0300707 , -0.04812494, -0.04883038,
#          -0.00963491, -0.00887865, -0.01811876,  0.04205158,
#           0.0070897 ,  0.00178963],
#         [-0.03186727,  0.00943171, -0.03389033, -0.04945372,
#           0.00779076, -0.01336875, -0.03982212, -0.01412457,
#           0.00549854,  0.02415103]],
#
#        [[ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [-0.04293237,  0.04571065, -0.01441659, -0.0030571 ,
#           0.04312602,  0.04845003, -0.04276825, -0.04221676,
#           0.04928776, -0.00744699],
#         [-0.02591617, -0.00051349,  0.03782333, -0.02742329,
#           0.00983693, -0.00701687, -0.04394136, -0.00390934,
#           0.01345844, -0.01327621],
#         [ 0.01799485,  0.01134251,  0.00370818, -0.02586728,
#          -0.01541474,  0.03493658,  0.00417228,  0.00058721,
#           0.02952598,  0.03778315],
#         [-0.01656395, -0.02776014, -0.00654156, -0.01475537,
#          -0.02967867,  0.04146253,  0.01982585, -0.02761208,
#          -0.00329828,  0.04715735],
#         [ 0.01967753,  0.02094349, -0.04946676,  0.02987834,
#           0.04707528,  0.04647354, -0.00073694,  0.02423904,
#          -0.00557213, -0.03956288]],
#
#        [[ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033,
#          -0.03133487,  0.00181317,  0.04882843,  0.04206527,
#          -0.0313372 , -0.0029693 ],
#         [ 0.02973205,  0.04140161,  0.00563239, -0.00490614,
#          -0.00616741,  0.03622449, -0.04059304, -0.00064196,
#          -0.00985289, -0.04686598],
#         [ 0.04374931,  0.03848937, -0.01692107,  0.02161287,
#           0.04763308, -0.04815958,  0.01510722, -0.00834392,
#           0.01871759,  0.01846517],
#         [ 0.01964385,  0.0166878 ,  0.01843873,  0.02008498,
#          -0.00704585, -0.02293297,  0.03674443, -0.00672451,
#           0.03122915, -0.01106586],
#         [-0.00636522, -0.0300707 , -0.04812494, -0.04883038,
#          -0.00963491, -0.00887865, -0.01811876,  0.04205158,
#           0.0070897 ,  0.00178963]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 5881, 2317, 1351, 7350], dtype=int32)

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 137ms/step
# array([[ 0.0346227 , -0.02082778, -0.00693996,  0.03412033, -0.03133487,
#          0.00181317,  0.04882843,  0.04206527, -0.0313372 , -0.0029693 ],
#        [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033, -0.03133487,
#          0.00181317,  0.04882843,  0.04206527, -0.0313372 , -0.0029693 ],
#        [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033, -0.03133487,
#          0.00181317,  0.04882843,  0.04206527, -0.0313372 , -0.0029693 ],
#        [ 0.0346227 , -0.02082778, -0.00693996,  0.03412033, -0.03133487,
#          0.00181317,  0.04882843,  0.04206527, -0.0313372 , -0.0029693 ],
#        [-0.02591617, -0.00051349,  0.03782333, -0.02742329,  0.00983693,
#         -0.00701687, -0.04394136, -0.00390934,  0.01345844, -0.01327621],
#        [-0.04100574,  0.02606461, -0.04599339,  0.02386352,  0.02503207,
#         -0.03597945, -0.0194989 ,  0.02387352,  0.00207195, -0.02740302],
#        [-0.01656395, -0.02776014, -0.00654156, -0.01475537, -0.02967867,
#          0.04146253,  0.01982585, -0.02761208, -0.00329828,  0.04715735],
#        [ 0.01212822, -0.00125396, -0.01668574, -0.00634258,  0.03437657,
#          0.01033913, -0.02537197,  0.03823092,  0.00948141, -0.0268918 ]],
#       dtype=float32)
